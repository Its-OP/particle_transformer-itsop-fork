# %%
# !git clone https://github.com/Its-OP/weaver-core-itsop-fork.git
# Out:
# Cloning into 'weaver-core-itsop-fork'...
# remote: Enumerating objects: 881, done.
# remote: Counting objects: 100% (430/430), done.
# remote: Compressing objects: 100% (150/150), done.
# remote: Total 881 (delta 348), reused 328 (delta 280), pack-reused 451 (from 1)
# Receiving objects: 100% (881/881), 221.19 KiB | 11.64 MiB/s, done.
# Resolving deltas: 100% (578/578), done.

# %%
# !cd weaver-core-itsop-fork && git pull
# Out:
# Already up to date.

# %%
# !git clone https://github.com/Its-OP/particle_transformer-itsop-fork.git
# Out:
# Cloning into 'particle_transformer-itsop-fork'...
# remote: Enumerating objects: 146, done.
# remote: Counting objects: 100% (86/86), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 146 (delta 67), reused 56 (delta 51), pack-reused 60 (from 2)
# Receiving objects: 100% (146/146), 28.09 MiB | 19.90 MiB/s, done.
# Resolving deltas: 100% (75/75), done.

# %%
# !cd particle_transformer-itsop-fork && git pull
# Out:
# Already up to date.

# %%
# !cd weaver-core-itsop-fork && pip install -e .
# Out:
# Obtaining file:///home/weaver-core-itsop-fork
# doneing metadata (setup.py) ...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.6/87.6 KB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 879.4/879.4 KB 28.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 32.9 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 37.1 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 47.9 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 60.4 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 MB 54.7 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.2/239.2 KB 110.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 97.6 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.6/37.6 MB 59.4 MB/s eta 0:00:0000:0100:01
# ...

# %%
# !echo "#!/bin/bash" > particle_transformer-itsop-fork/env.sh
# !echo >> particle_transformer-itsop-fork/env.sh
# !echo "export DATADIR_JetClass=" >> particle_transformer-itsop-fork/env.sh
# !echo "export DATADIR_TopLandscape=/home" >> particle_transformer-itsop-fork/env.sh
# !echo "export DATADIR_QuarkGluon=" >> particle_transformer-itsop-fork/env.sh
# !echo "export gpus=0" >> particle_transformer-itsop-fork/env.sh
# !echo "export batchsize=512" >> particle_transformer-itsop-fork/env.sh
# !echo "export optimizer=soap" >> particle_transformer-itsop-fork/env.sh
# !echo "export weight_decay=0.01" >> particle_transformer-itsop-fork/env.sh
# !echo "export lr=0.003" >> particle_transformer-itsop-fork/env.sh
# !echo "export scheduler=flat+decay" >> particle_transformer-itsop-fork/env.sh
# !echo "export num_epochs=20" >> particle_transformer-itsop-fork/env.sh
# !echo "export warmup_steps=10" >> particle_transformer-itsop-fork/env.sh

# %%
# !cd particle_transformer-itsop-fork && ./train_TopLandscape.sh ParT kin
# Out:
# + source env.sh
# ++ export DATADIR_JetClass=
# ++ DATADIR_JetClass=
# ++ export DATADIR_TopLandscape=/home
# ++ DATADIR_TopLandscape=/home
# ++ export DATADIR_QuarkGluon=
# ++ DATADIR_QuarkGluon=
# ++ export gpus=0
# ++ gpus=0
# ++ export batchsize=512
# ++ batchsize=512
# ++ export optimizer=soap
# ++ optimizer=soap
# ++ export weight_decay=0.01
# ++ weight_decay=0.01
# ++ export lr=0.003
# ++ lr=0.003
# ++ export scheduler=flat+decay
# ++ scheduler=flat+decay
# ++ export num_epochs=20
# ++ num_epochs=20
# ++ export warmup_steps=10
# ++ warmup_steps=10
# + echo 'args: ParT' kin
# args: ParT kin
# + DATADIR=/home
# + [[ -z /home ]]
# + suffix=
# + model=ParT
# + extraopts=
# + [[ ParT == \P\a\r\T ]]
# + modelopts='networks/example_ParticleTransformer.py --use-amp --optimizer-option weight_decay 0.01'
# + FEATURE_TYPE=kin
# + [[ -z kin ]]
# + [[ kin != \k\i\n ]]
# ...
